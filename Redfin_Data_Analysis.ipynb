# %% [markdown]
# # Data Set
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import seaborn as sns
#
# df=pd.read_csv('scrape_data_v2.csv', sep=',',index_col=0)
# df

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
import seaborn as sns

df=pd.read_csv('scrape_data_v2.csv', sep=',',index_col=0) 
df
# Out:
#                            street      city state  zipcode    price  bed  \
# 1             2260 A San Jose Ave   Alameda    CA    94501   689000  1.0
# 2                   888 Willow St   Alameda    CA    94501  1680000  5.0
# 3                1071 Melrose Ave   Alameda    CA    94502   699000  2.0
# 4                1041 Melrose Ave   Alameda    CA    94502   929000  3.0
# 6            1837 Santa Clara Ave   Alameda    CA    94501  1280000  5.0
# ..                            ...       ...   ...      ...      ...  ...
# 873              1635 Starlite Dr  Milpitas    CA    95035  1398888  5.0
# 874  49002 Cinnamon Fern Cmn #214   Fremont    CA    94539   899888  2.0
# 875             109 Parc Place Dr  Milpitas    CA    95035   960000  3.0
# 876           484 Dempsey Rd #186  Milpitas    CA    95035   385000  1.0
# 877            1916 Terracotta Ct  Milpitas    CA    95035  1485995  3.0
#
#      bath    sqft  walkscore  transitscore  bikescore  competitivescore  \
# 1     1.0   572.0         91          49.0       74.0              87.0
# 2     5.5  3090.0         78          47.0       70.0              87.0
# 3     2.0  1247.0         43          30.0       55.0              92.0
# 4     2.5  1738.0         42          30.0       55.0              92.0
# 6     1.5  2310.0         85          48.0       82.0              87.0
# ..    ...     ...        ...           ...        ...               ...
# 873   2.5  1692.0         35          47.0       60.0              85.0
# 874   2.0  1274.0         60          38.0       71.0              72.0
# 875   2.0  1530.0         77          48.0       77.0              73.0
# 876   1.0   676.0         70          26.0       69.0              85.0
# 877   3.0  1979.0         69          60.0       77.0              86.0
#
#      price_per_sqft
# 1           1204.55
# 2            543.69
# 3            560.55
# 4            534.52
# 6            554.11
# ..              ...
# 873          826.77
# 874          706.35
# 875          627.45
# 876          569.53
# 877          750.88
#
# [814 rows x 13 columns]

# %% [markdown]
# # Columns in Data Set

# %%
df.columns
# Out:
# Index(['street', 'city', 'state', 'zipcode', 'price', 'bed', 'bath', 'sqft',
#        'walkscore', 'transitscore', 'bikescore', 'competitivescore',
#        'price_per_sqft'],
#       dtype='object')

# %% [markdown]
# # Total Unique cities in data set

# %%
df.city.unique()
# Out:
# array(['Alameda', 'Albany', 'Belmont', 'Berkeley', 'Burlingame',
#        'Cupertino', 'Daly city', 'Dublin', 'Emeryville', 'Fremont',
#        'Fresno', 'Gilroy', 'Hayward', 'Irvine', 'Lafayette', 'Livermore',
#        'Long beach', 'Los angeles', 'Mill valley', 'Moraga',
#        'Morgan hill', 'Moss beach', 'Mountain view', 'Newark', 'Oakland',
#        'Orinda', 'Pacifica', 'Palo alto', 'Piedmont', 'Pleasanton',
#        'Riverside', 'Sacramento', 'San bruno', 'San diego',
#        'San francisco', 'San jose', 'San leandro', 'San lorenzo',
#        'San luis obispo', 'San mateo', 'Santa barbara', 'Santa clara',
#        'Santa rosa', 'Saratoga', 'Stockton', 'Sunnyvale', 'Los gatos',
#        'Campbell', 'Milpitas', 'Monte sereno', 'Los altos',
#        'Castro valley', 'Union city'], dtype=object)

# %%
new_df=df[(df.city=='Alameda')|(df.city=='Berkeley')|(df.city=='Campbell')|(df.city=='Cupertino')|(df.city=='Fremont')|(df.city=='Gilroy')|(df.city=='Hayward')|(df.city=='Livermore')|(df.city=='Los angeles') |(df.city=='Milpitas')|(df.city=='Morgan hill')|(df.city=='Mountain view') |(df.city=='Newark') |(df.city=='Oakland')|(df.city=='Riverside')]
new_df
# Out:
#                            street      city state  zipcode    price  bed  \
# 1             2260 A San Jose Ave   Alameda    CA    94501   689000  1.0
# 2                   888 Willow St   Alameda    CA    94501  1680000  5.0
# 3                1071 Melrose Ave   Alameda    CA    94502   699000  2.0
# 4                1041 Melrose Ave   Alameda    CA    94502   929000  3.0
# 6            1837 Santa Clara Ave   Alameda    CA    94501  1280000  5.0
# ..                            ...       ...   ...      ...      ...  ...
# 873              1635 Starlite Dr  Milpitas    CA    95035  1398888  5.0
# 874  49002 Cinnamon Fern Cmn #214   Fremont    CA    94539   899888  2.0
# 875             109 Parc Place Dr  Milpitas    CA    95035   960000  3.0
# 876           484 Dempsey Rd #186  Milpitas    CA    95035   385000  1.0
# 877            1916 Terracotta Ct  Milpitas    CA    95035  1485995  3.0
#
#      bath    sqft  walkscore  transitscore  bikescore  competitivescore  \
# 1     1.0   572.0         91          49.0       74.0              87.0
# 2     5.5  3090.0         78          47.0       70.0              87.0
# 3     2.0  1247.0         43          30.0       55.0              92.0
# 4     2.5  1738.0         42          30.0       55.0              92.0
# 6     1.5  2310.0         85          48.0       82.0              87.0
# ..    ...     ...        ...           ...        ...               ...
# 873   2.5  1692.0         35          47.0       60.0              85.0
# 874   2.0  1274.0         60          38.0       71.0              72.0
# 875   2.0  1530.0         77          48.0       77.0              73.0
# 876   1.0   676.0         70          26.0       69.0              85.0
# 877   3.0  1979.0         69          60.0       77.0              86.0
#
#      price_per_sqft
# 1           1204.55
# 2            543.69
# 3            560.55
# 4            534.52
# 6            554.11
# ..              ...
# 873          826.77
# 874          706.35
# 875          627.45
# 876          569.53
# 877          750.88
#
# [378 rows x 13 columns]

# %% [markdown]
# # City Wise Minimum/Maximum and Avg Price Details

# %%
new_data = new_df.groupby('city')['price'].agg({'min','max','mean'}).round(2)
print(new_data)
# Out:
#                    max        mean     min
# city
# Alameda        2900000  1116481.00  419000
# Berkeley       2350000  1349750.00  895000
# Campbell       1350000  1042333.33  879000
# Cupertino      6500000  2635361.00  910000
# Fremont        2519000  1278984.00  685000
# Gilroy         3650000  1283068.80  252900
# Hayward        2480000   801040.77  227000
# Livermore      2200000  1253286.22  664900
# Los angeles    2499000  1266000.00  649000
# Milpitas       1988000  1093088.19  385000
# Morgan hill    1688000  1120833.33  669000
# Mountain view  3498000  2245680.44  898000
# Newark         1788000  1182000.00  799000
# Oakland        3400000  1072320.68  599999
# Riverside      1239999   982249.00  724499

# %% [markdown]
# # City Wise Minimum/Maximum and Avg Price Details

# %%
sns.relplot(data=new_data, kind='line',
            height=5, aspect=1,linestyle='solid'
           )

plt.title('City wise Min/Max/Avg Chart')
plt.ylabel('Price range(in hundred thousands)')
plt.xlabel('Cities')
plt.subplots_adjust(right=2, top=1.5, left=0.01, bottom=0.01)
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,ncol=1)

# %% [markdown]
# # Printing columns such as city, state, price and bed

# %%
df[['city', 'state', 'price', 'bed']].head(10)
# Out:
#        city state    price  bed
# 1   Alameda    CA   689000  1.0
# 2   Alameda    CA  1680000  5.0
# 3   Alameda    CA   699000  2.0
# 4   Alameda    CA   929000  3.0
# 6   Alameda    CA  1280000  5.0
# 7   Alameda    CA  1398000  3.0
# 8   Alameda    CA   775000  4.0
# 9   Alameda    CA   950000  3.0
# 10  Alameda    CA  1765000  4.0
# 11  Alameda    CA  1298000  3.0

# %% [markdown]
# # Checking for null values if any

# %%
df.isnull().sum()
# Out:
# street              0
# city                0
# state               0
# zipcode             0
# price               0
# bed                 0
# bath                0
# sqft                0
# walkscore           0
# transitscore        0
# bikescore           0
# competitivescore    0
# price_per_sqft      0
# dtype: int64

# %% [markdown]
# # Total number of apartments in different cities across California

# %%
highest_count_houses = df['city'].value_counts() 
print(highest_count_houses)

plt.figure(figsize=(10,7))
highest_count_houses[:5].plot(kind = "bar",color = 'b')
plt.title('Top 5 Cities with Highest Count of houses in California')
plt.xticks(rotation = 45)
# Out:
# San francisco      263
# Alameda            124
# Hayward             83
# Oakland             53
# San jose            51
# Milpitas            43
# Mountain view       16
# Sunnyvale           13
# San luis obispo     10
# San diego           10
# Gilroy              10
# Pleasanton          10
# Santa rosa           9
# Livermore            9
# Cupertino            8
# Berkeley             8
# Fremont              7
# Morgan hill          6
# Santa clara          6
# Daly city            6
# Dublin               5
# San leandro          5
# Palo alto            5
# Los gatos            4
# Los angeles          3
# Newark               3
# Piedmont             3
# San mateo            3
# Santa barbara        3
# Campbell             3
# Saratoga             3
# Sacramento           3
# Pacifica             2
# San bruno            2
# San lorenzo          2
# Orinda               2
# Riverside            2
# Castro valley        1
# Albany               1
# Mill valley          1
# Stockton             1
# Moss beach           1
# Burlingame           1
# Lafayette            1
# Moraga               1
# Monte sereno         1
# Fresno               1
# Irvine               1
# Los altos            1
# Belmont              1
# Union city           1
# Emeryville           1
# Long beach           1
# Name: city, dtype: int64
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'San francisco'),
#   Text(1, 0, 'Alameda'),
#   Text(2, 0, 'Hayward'),
#   Text(3, 0, 'Oakland'),
#   Text(4, 0, 'San jose')])

# %% [markdown]
# # Total number of apartments as per number of bed

# %%
#Total Number of beds

c = df.sort_values(by='bed')
Series=c['bed'].value_counts() 
Series
# Out:
# 3.0     315
# 2.0     187
# 4.0     177
# 5.0      55
# 1.0      47
# 6.0      17
# 8.0       7
# 7.0       6
# 9.0       2
# 11.0      1
# Name: bed, dtype: int64

# %% [markdown]
# # Crosstable for total number of apartments with 1,2,3,4 and 5 bed in San Francisco, Alameda, Hayward, Oakland and San Jose

# %%
#number of houses with 1,2,3,4 and 5 bed in different cities

xt = pd.crosstab(df['city'],df['bed'])
xt.loc[['San francisco','Alameda','Hayward', 'Oakland', 'San jose'],[1,2,3,4,5]]
# Out:
# bed             1   2   3   4   5
# city
# San francisco  30  73  87  48  15
# Alameda         6  39  42  17   7
# Hayward         1  23  48  11   0
# Oakland         1  11  19  12   7
# San jose        0   9  21  15   6

# %% [markdown]
# # Plotting bar graph for total number of apartments with 1,2,3,4 and 5 bed in San Francisco, Alameda, Hayward, Oakland and San Jose

# %%
xt.loc[['San francisco','Alameda','Hayward', 'Oakland', 'San jose'],[1,2,3,4,5]].plot.bar(figsize=(10,7))

plt.title('Count of 1,2,3,4,& 5 bed house')
plt.ylabel('bed Count')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'San francisco'),
#   Text(1, 0, 'Alameda'),
#   Text(2, 0, 'Hayward'),
#   Text(3, 0, 'Oakland'),
#   Text(4, 0, 'San jose')])

# %% [markdown]
# # Average price of House per bed in San Francisco, Alameda, Hayward, Oakland and San Jose

# %%
#Average price of house per bed in different cities
bed_average_price = df.groupby(['city','bed']).mean()
x = bed_average_price['price'].astype(np.int64)
x[['San francisco','Alameda','Hayward', 'Oakland', 'San jose']]
# Out:
# city           bed
# San francisco  1.0     870468
#                2.0    1386116
#                3.0    1683325
#                4.0    2339518
#                5.0    3166932
#                6.0    2290314
#                7.0    4292500
#                8.0    8145000
# Alameda        1.0     501166
#                2.0     805934
#                3.0    1097681
#                4.0    1383445
#                5.0    1807857
#                6.0    1441166
#                7.0    1662666
#                8.0    1849000
#                9.0    2198000
# Hayward        1.0     699888
#                2.0     589032
#                3.0     793728
#                4.0    1285434
# Oakland        1.0     669000
#                2.0     757545
#                3.0     959789
#                4.0    1131499
#                5.0    1367000
#                6.0    1950000
#                8.0    2249000
# San jose       2.0     738864
#                3.0    1146836
#                4.0    1561699
#                5.0    2202333
# Name: price, dtype: int64

# %% [markdown]
# # Crosstable for Average price of House per bed in San Francisco, Alameda, Hayward, Oakland and San Jose

# %%
#Average price of house with 1,2,3,4 and 5 bed in top 5 cities

ct = pd.crosstab(index=df['city'], columns=df['bed'], values=df['price'], margins=True, aggfunc='mean').replace(np.nan, 0).astype(np.int64)

ct.loc[['San francisco','Alameda','Hayward', 'Oakland', 'San jose'],[1,2,3,4,5]]
# Out:
# bed                 1        2        3        4        5
# city
# San francisco  870468  1386116  1683325  2339518  3166932
# Alameda        501166   805934  1097681  1383445  1807857
# Hayward        699888   589032   793728  1285434        0
# Oakland        669000   757545   959789  1131499  1367000
# San jose            0   738864  1146836  1561699  2202333

# %% [markdown]
# # Plotting Average price of House per bed in San Francisco, Alameda, Hayward, Oakland and San Jose

# %%
#Average prices of house per bed

ct.loc[['San francisco','Alameda','Hayward', 'Oakland', 'San jose'],[1,2,3,4,5]].plot.bar(figsize=(10,7))

plt.title('Average Price of 1,2,3,4,& 5 bed house')
plt.ylabel('Avg Price in Millions $')
plt.legend(loc = 'upper right', ncol = 1, title = "Bed")
plt.xticks(rotation = 45)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'San francisco'),
#   Text(1, 0, 'Alameda'),
#   Text(2, 0, 'Hayward'),
#   Text(3, 0, 'Oakland'),
#   Text(4, 0, 'San jose')])

# %% [markdown]
# # Data set

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('scrape_data_v2.csv',index_col=0)
df.head()
# Out:
#                  street     city state  zipcode    price  bed  bath    sqft  \
# 1   2260 A San Jose Ave  Alameda    CA    94501   689000  1.0   1.0   572.0
# 2         888 Willow St  Alameda    CA    94501  1680000  5.0   5.5  3090.0
# 3      1071 Melrose Ave  Alameda    CA    94502   699000  2.0   2.0  1247.0
# 4      1041 Melrose Ave  Alameda    CA    94502   929000  3.0   2.5  1738.0
# 6  1837 Santa Clara Ave  Alameda    CA    94501  1280000  5.0   1.5  2310.0
#
#    walkscore  transitscore  bikescore  competitivescore  price_per_sqft
# 1         91          49.0       74.0              87.0         1204.55
# 2         78          47.0       70.0              87.0          543.69
# 3         43          30.0       55.0              92.0          560.55
# 4         42          30.0       55.0              92.0          534.52
# 6         85          48.0       82.0              87.0          554.11

# %% [markdown]
# # Average price of price_per_sqft for all the cities of California

# %%
import pandas as pd
a = df.groupby(by="city")
b=pd.DataFrame(a['price_per_sqft'].mean())
b
# Out:
#                  price_per_sqft
# city
# Alameda              655.625726
# Albany               807.670000
# Belmont              836.710000
# Berkeley             847.841250
# Burlingame          1237.960000
# Campbell             878.263333
# Castro valley        578.520000
# Cupertino           1299.191250
# Daly city            732.920000
# Dublin               500.542000
# Emeryville           583.470000
# Fremont              675.358571
# Fresno               168.070000
# Gilroy               480.232000
# Hayward              580.609157
# Irvine               544.920000
# Lafayette            601.110000
# Livermore            545.734444
# Long beach           399.000000
# Los altos           2764.610000
# Los angeles          561.780000
# Los gatos           1135.967500
# Mill valley          778.650000
# Milpitas             717.543488
# Monte sereno        1627.950000
# Moraga               438.460000
# Morgan hill          649.880000
# Moss beach          2187.500000
# Mountain view       1227.510000
# Newark               554.606667
# Oakland              575.132264
# Orinda               777.225000
# Pacifica             778.250000
# Palo alto           1835.578000
# Piedmont             821.863333
# Pleasanton           694.013000
# Riverside            259.480000
# Sacramento           362.890000
# San bruno            807.090000
# San diego            575.814000
# San francisco       1002.945019
# San jose             754.152745
# San leandro          562.314000
# San lorenzo          632.335000
# San luis obispo      596.825000
# San mateo            844.613333
# Santa barbara        963.110000
# Santa clara          791.496667
# Santa rosa           545.473333
# Saratoga            1259.546667
# Stockton             348.840000
# Sunnyvale            850.565385
# Union city           760.420000

# %% [markdown]
# # Top 5 and Bottom 5 cities in CA as per the Average price per square feet

# %%
Top5= pd.DataFrame(b.sort_values(by = 'price_per_sqft',ascending=False).head(5))
print(Top5)
Top5['Stack'] = 'Top5'
Bottom5= pd.DataFrame(b.sort_values(by = 'price_per_sqft',ascending=False).tail(5))
print(Bottom5)
Bottom5['Stack'] = 'Bottom5'
# Out:
#               price_per_sqft
# city
# Los altos         2764.61000
# Moss beach        2187.50000
# Palo alto         1835.57800
# Monte sereno      1627.95000
# Cupertino         1299.19125
#             price_per_sqft
# city
# Long beach          399.00
# Sacramento          362.89
# Stockton            348.84
# Riverside           259.48
# Fresno              168.07

# %% [markdown]
# # Top 5 cities in CA as per the Average price per square feet

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

Top5.plot(kind='barh',color='lightgreen',figsize=(8,6))
plt.xlabel("Avg Price_per_sqft")
plt.ylabel("City") 
plt.suptitle('City-Avg Price per Sqft')
plt.show()

# %% [markdown]
# # Bottom 5 cities in CA as per the Average price per square feet

# %%
Bottom5.plot(kind='bar',color='lightgreen',figsize=(8,6))
plt.xlabel("City")
plt.ylabel("Avg Price_per_sqft") 
plt.suptitle('City-Avg Price per Sqft')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Variation in Transit score as per city

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

data_df = pd.read_csv('scrape_data_v2.csv',index_col=0)
df = data_df.dropna(subset=['street', 'city', 'price', 'transitscore'])

sns.set_theme(style="ticks", color_codes=True)
g = sns.catplot(x="city", y="transitscore", data=df, height=10, aspect=20/10, kind='swarm')
g.set_xticklabels(rotation=90)

# %% [markdown]
# # How good is the city transit system
#
# 90–100 Rider's Paradise (World-class public transportation) <br>
# 70–89 Excellent Transit (Transit is convenient for most trips) <br>
# 50–69 Good Transit (Many nearby public transportation options) <br>
# 25–49 Some Transit (A few nearby public transportation options) <br>
# 0–24 Minimal Transit (It is possible to get on a bus)

# %%
transit_score_desc_list = []
for t in df['transitscore']:
    if t <= 100 and t >= 90:
        transit_score_desc_list.append('Rider\'s Paradise')
    elif t <= 89 and t >= 70:
        transit_score_desc_list.append('Excellent Transit')
    elif t <= 69 and t >= 50:
        transit_score_desc_list.append('Good Transit')
    elif t <= 49 and t >= 25:
        transit_score_desc_list.append('Some Transit')
    elif t <= 24 and t >= 0:
        transit_score_desc_list.append('Minimal Transit')
    else:
        transit_score_desc_list.append('')
df['transitscore_desc'] = transit_score_desc_list
g = pd.crosstab(df['city'], df['transitscore_desc'])
cities_8 = ['San francisco', 'Alameda', 'Hayward', 'Oakland', 'San jose', 'Milpitas', 'Mountain view', 'Sunnyvale']
unique_ts = list(df['transitscore_desc'].unique())
g.loc[cities_8, unique_ts].plot.bar(figsize=(10,8))
plot.xlabel('City')
plot.ylabel('Count')
plot.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'San francisco'),
#   Text(1, 0, 'Alameda'),
#   Text(2, 0, 'Hayward'),
#   Text(3, 0, 'Oakland'),
#   Text(4, 0, 'San jose'),
#   Text(5, 0, 'Milpitas'),
#   Text(6, 0, 'Mountain view'),
#   Text(7, 0, 'Sunnyvale')])

# %% [markdown]
# # Affect of transit system availability over house prices

# %%
# Price range based on the transit score (averaged for each city)
plot.figure(figsize=(10,10))
sns.boxplot(x="transitscore_desc", y="price", data=df)
plot.ticklabel_format(style='plain', axis='y')
plot.ylim(0, 7000000)
plot.ylabel("Price")
plot.xlabel("Transit Score Description")
plot.title("Correlation between Price and Transit Scores")
# Out:
# Text(0.5, 1.0, 'Correlation between Price and Transit Scores')
